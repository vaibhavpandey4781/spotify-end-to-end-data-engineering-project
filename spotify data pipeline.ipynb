# %%
# !pip install spotipy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\PC\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
import sys
# !{sys.executable} -m pip install spotipy
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager= SpotifyClientCredentials(client_id="4cd1fff481c04379b19c95701566cb74",client_secret="45d6efb1228241fa8208b6e21b1299f4")

# %%
 #object creation to extract data and help in authorization/permission set up client manager: 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/3bDJLJzvUBxBV4C7mezz6p"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
playlist_URI
# Out:
# '3bDJLJzvUBxBV4C7mezz6p'

# %%
data =sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2025-06-20T14:24:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/9s87naeckijnd6qs439icv9h1'},
#    'href': 'https://api.spotify.com/v1/users/9s87naeckijnd6qs439icv9h1',
#    'id': '9s87naeckijnd6qs439icv9h1',
#    'type': 'user',
#    'uri': 'spotify:user:9s87naeckijnd6qs439icv9h1'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
len(data['items'])
# Out:
# 100

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '3ETAyPs1TjEcYIpCbYwEbk'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Saiyaara (From "Saiyaara")'

# %%
data['items'][0]['track']['album']['images']
# Out:
# [{'height': 640,
#   'url': 'https://i.scdn.co/image/ab67616d0000b273a7e251b543c77a6ed356dfbe',
#   'width': 640},
#  {'height': 300,
#   'url': 'https://i.scdn.co/image/ab67616d00001e02a7e251b543c77a6ed356dfbe',
#   'width': 300},
#  {'height': 64,
#   'url': 'https://i.scdn.co/image/ab67616d00004851a7e251b543c77a6ed356dfbe',
#   'width': 64}]

# %%
data['items'][0]['track']['album']['images'][0]['url']
# Out:
# 'https://i.scdn.co/image/ab67616d0000b273a7e251b543c77a6ed356dfbe'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/3ETAyPs1TjEcYIpCbYwEbk'

# %%
album_list=[]
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '3ETAyPs1TjEcYIpCbYwEbk',
#   'name': 'Saiyaara (From "Saiyaara")',
#   'release_date': '2025-06-03',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3ETAyPs1TjEcYIpCbYwEbk'},
#  {'album_id': '250nGZusEhq33ZIZYJ7eVb',
#   'name': 'Sahiba',
#   'release_date': '2023-12-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/250nGZusEhq33ZIZYJ7eVb'},
#  {'album_id': '69oxllULO1PeIO1VHT97uk',
#   'name': 'Tum Ho Toh (From "Saiyaara")',
#   'release_date': '2025-06-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/69oxllULO1PeIO1VHT97uk'},
#  {'album_id': '7oUQEGYiwyjH8OFCu5Y4IG',
#   'name': 'Dhun (From "Saiyaara")',
#   'release_date': '2025-07-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7oUQEGYiwyjH8OFCu5Y4IG'},
#  {'album_id': '27wFxpV56Pg7Uxk0GxNfoF',
#   'name': 'Barbaad (From "Saiyaara")',
#   'release_date': '2025-06-10',
#   'total_tracks': 1,
# ...

# %%
album_list = []

for row in data['items']:
    try:
        album = row['track']['album']
        album_element = {
            'album_id': album.get('id'),
            'name': album.get('name'),
            'release_date': album.get('release_date'),
            'total_tracks': album.get('total_tracks'),
            'url': album.get('external_urls', {}).get('spotify')
        }
        album_list.append(album_element)
    except KeyError as e:
        print(f"Missing key in row: {e}")

# %%
album_list
# Out:
# [{'album_id': '3ETAyPs1TjEcYIpCbYwEbk',
#   'name': 'Saiyaara (From "Saiyaara")',
#   'release_date': '2025-06-03',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3ETAyPs1TjEcYIpCbYwEbk'},
#  {'album_id': '250nGZusEhq33ZIZYJ7eVb',
#   'name': 'Sahiba',
#   'release_date': '2023-12-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/250nGZusEhq33ZIZYJ7eVb'},
#  {'album_id': '69oxllULO1PeIO1VHT97uk',
#   'name': 'Tum Ho Toh (From "Saiyaara")',
#   'release_date': '2025-06-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/69oxllULO1PeIO1VHT97uk'},
#  {'album_id': '7oUQEGYiwyjH8OFCu5Y4IG',
#   'name': 'Dhun (From "Saiyaara")',
#   'release_date': '2025-07-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7oUQEGYiwyjH8OFCu5Y4IG'},
#  {'album_id': '27wFxpV56Pg7Uxk0GxNfoF',
#   'name': 'Barbaad (From "Saiyaara")',
#   'release_date': '2025-06-10',
#   'total_tracks': 1,
# ...

# %%
data['items'][15]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05etL4pzWd6TSv1x5WrlG3'},
#   'href': 'https://api.spotify.com/v1/artists/05etL4pzWd6TSv1x5WrlG3',
#   'id': '05etL4pzWd6TSv1x5WrlG3',
#   'name': 'Faheem Abdullah',
#   'type': 'artist',
#   'uri': 'spotify:artist:05etL4pzWd6TSv1x5WrlG3'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7bSCXFT0iT4kcgsAZ6h8Qy'},
#   'href': 'https://api.spotify.com/v1/artists/7bSCXFT0iT4kcgsAZ6h8Qy',
#   'id': '7bSCXFT0iT4kcgsAZ6h8Qy',
#   'name': 'Huzaif Nazar',
#   'type': 'artist',
#   'uri': 'spotify:artist:7bSCXFT0iT4kcgsAZ6h8Qy'}]

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key== "track":
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

artist_list
# Out:
# [{'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '05etL4pzWd6TSv1x5WrlG3',
#   'artist_name': 'Faheem Abdullah',
#   'external_url': 'https://api.spotify.com/v1/artists/05etL4pzWd6TSv1x5WrlG3'},
#  {'artist_id': '5yzqUq3vXrMkmfcOwMY203',
#   'artist_name': 'Arslan Nizami',
#   'external_url': 'https://api.spotify.com/v1/artists/5yzqUq3vXrMkmfcOwMY203'},
#  {'artist_id': '3GdSQUH1BRtl9UrrtuwJlP',
#   'artist_name': 'Irshad Kamil',
#   'external_url': 'https://api.spotify.com/v1/artists/3GdSQUH1BRtl9UrrtuwJlP'},
#  {'artist_id': '3ozYqVCLohfpXIhalkhM8D',
#   'artist_name': 'Aditya Rikhari',
#   'external_url': 'https://api.spotify.com/v1/artists/3ozYqVCLohfpXIhalkhM8D'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)
song_list
# Out:
# [{'song_id': '1D35BJlymlh6OLD75WupSF',
#   'song_name': 'Saiyaara (From "Saiyaara")',
#   'duration_ms': 370875,
#   'url': 'https://open.spotify.com/track/1D35BJlymlh6OLD75WupSF',
#   'popularity': 90,
#   'song_added': '2025-06-20T14:24:17Z',
#   'album_id': '3ETAyPs1TjEcYIpCbYwEbk',
#   'artist_id': '4f7KfxeHq9BiylGmyXepGt'},
#  {'song_id': '0eLtIxPRNJfsmehITZ1qaJ',
#   'song_name': 'Sahiba',
#   'duration_ms': 190098,
#   'url': 'https://open.spotify.com/track/0eLtIxPRNJfsmehITZ1qaJ',
#   'popularity': 86,
#   'song_added': '2025-07-11T13:39:24Z',
#   'album_id': '250nGZusEhq33ZIZYJ7eVb',
#   'artist_id': '3ozYqVCLohfpXIhalkhM8D'},
#  {'song_id': '6G8vN5EUtcDxOXOXadF6kp',
#   'song_name': 'Tum Ho Toh (From "Saiyaara")',
#   'duration_ms': 318217,
#   'url': 'https://open.spotify.com/track/6G8vN5EUtcDxOXOXadF6kp',
#   'popularity': 81,
#   'song_added': '2025-07-25T14:52:53Z',
#   'album_id': '69oxllULO1PeIO1VHT97uk',
#   'artist_id': '5wJ1H6ud777odtZl5gG507'},
# ...

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.tail(54)
# Out:
#                   album_id                                               name  \
# 42  3uuu6u13U0KeVQsZ3CZKK4                                        Kabir Singh
# 43  3MgVvOPyK1wPFEM9l7AQFr                                           Do Patti
# 45  5K0rFYotIyeCXpmNVzWpfn   Blood Money (Original Motion Picture Soundtrack)
# 46  3D4OuBfCaBO8FnY5RiZVIj                       Jugraafiya (From "Super 30")
# 47  5H5qWXVkPtu1TXb7sLfckt                                               Wavy
# 49  4FjR8sS5OickJ0OkXmOEXX                                             Sitara
# 50  0Rkv5iqjF2uenfL0OVB8hg                                         Aashiqui 2
# 51  3PxXJhlxSQkj8JO7IXy0FE  Hasee Toh Phasee (Original Motion Picture Soun...
# 52  5iQWs6EDVerd6MxgYbsgKX                                    Jhol (Acoustic)
# 53  0RaKe6idrXFUXsqxU4VmPa                                              Afsos
# 55  3I3kZyHUtEA9Y59rJkxtk6                     Sajni (From "Laapataa Ladies")
# ...

# %%
artist_df=pd.DataFrame.from_dict(artist_list)
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id      artist_name  \
# 0  4f7KfxeHq9BiylGmyXepGt   Tanishk Bagchi
# 1  05etL4pzWd6TSv1x5WrlG3  Faheem Abdullah
# 2  5yzqUq3vXrMkmfcOwMY203    Arslan Nizami
# 3  3GdSQUH1BRtl9UrrtuwJlP     Irshad Kamil
# 4  3ozYqVCLohfpXIhalkhM8D   Aditya Rikhari
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4f7KfxeHq9B...
# 1  https://api.spotify.com/v1/artists/05etL4pzWd6...
# 2  https://api.spotify.com/v1/artists/5yzqUq3vXrM...
# 3  https://api.spotify.com/v1/artists/3GdSQUH1BRt...
# 4  https://api.spotify.com/v1/artists/3ozYqVCLohf...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
song_df=pd.DataFrame.from_dict(song_list)
song_df=song_df.drop_duplicates(subset=['song_id'])

# %%
song_df.head()
# Out:
#                   song_id                     song_name  duration_ms  \
# 0  1D35BJlymlh6OLD75WupSF    Saiyaara (From "Saiyaara")       370875
# 1  0eLtIxPRNJfsmehITZ1qaJ                        Sahiba       190098
# 2  6G8vN5EUtcDxOXOXadF6kp  Tum Ho Toh (From "Saiyaara")       318217
# 3  1GFQthxDi4Tqe3wJ5j0G5S        Dhun (From "Saiyaara")       276643
# 4  7Csa4PStpuYIfUqNMKQ4V8     Barbaad (From "Saiyaara")       357127
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/1D35BJlymlh6OLD...          90
# 1  https://open.spotify.com/track/0eLtIxPRNJfsmeh...          86
# 2  https://open.spotify.com/track/6G8vN5EUtcDxOXO...          81
# 3  https://open.spotify.com/track/1GFQthxDi4Tqe3w...          82
# 4  https://open.spotify.com/track/7Csa4PStpuYIfUq...          80
#
#              song_added                album_id               artist_id
# 0  2025-06-20T14:24:17Z  3ETAyPs1TjEcYIpCbYwEbk  4f7KfxeHq9BiylGmyXepGt
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce', infer_datetime_format=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_6016\2842982473.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce', infer_datetime_format=True)
# C:\Users\PC\AppData\Local\Temp\ipykernel_6016\2842982473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce', infer_datetime_format=True)

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'], errors='coerce', infer_datetime_format=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_6016\826869815.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   song_df['song_added'] = pd.to_datetime(song_df['song_added'], errors='coerce', infer_datetime_format=True)

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      93 non-null     object
#  1   name          93 non-null     object
#  2   release_date  92 non-null     datetime64[ns]
#  3   total_tracks  93 non-null     int64
#  4   url           93 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.4+ KB

# %%
results = sp.search(q='Arijit Singh', type='artist')
print(results['artists']['items'][0]['name'])
# Out:
# Arijit Singh

# %%
data['items'][15]['track']['name']
# Out:
# 'Sajde'

# %%
for key, value in data['items'][0].items():
    print(key, ":", value)
# Out:
# added_at : 2025-06-20T14:24:17Z
# added_by : {'external_urls': {'spotify': 'https://open.spotify.com/user/9s87naeckijnd6qs439icv9h1'}, 'href': 'https://api.spotify.com/v1/users/9s87naeckijnd6qs439icv9h1', 'id': '9s87naeckijnd6qs439icv9h1', 'type': 'user', 'uri': 'spotify:user:9s87naeckijnd6qs439icv9h1'}
# is_local : False
# primary_color : None
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '05etL4pzWd6TSv1x5WrlG3',
#   'artist_name': 'Faheem Abdullah',
#   'external_url': 'https://api.spotify.com/v1/artists/05etL4pzWd6TSv1x5WrlG3'},
#  {'artist_id': '5yzqUq3vXrMkmfcOwMY203',
#   'artist_name': 'Arslan Nizami',
#   'external_url': 'https://api.spotify.com/v1/artists/5yzqUq3vXrMkmfcOwMY203'},
#  {'artist_id': '3GdSQUH1BRtl9UrrtuwJlP',
#   'artist_name': 'Irshad Kamil',
#   'external_url': 'https://api.spotify.com/v1/artists/3GdSQUH1BRtl9UrrtuwJlP'},
#  {'artist_id': '3ozYqVCLohfpXIhalkhM8D',
#   'artist_name': 'Aditya Rikhari',
#   'external_url': 'https://api.spotify.com/v1/artists/3ozYqVCLohfpXIhalkhM8D'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
# ...

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3bDJLJzvUBxBV4C7mezz6p/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-06-20T14:24:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/9s87naeckijnd6qs439icv9h1'},
#     'href': 'https://api.spotify.com/v1/users/9s87naeckijnd6qs439icv9h1',
#     'id': '9s87naeckijnd6qs439icv9h1',
#     'type': 'user',
#     'uri': 'spotify:user:9s87naeckijnd6qs439icv9h1'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2025-06-20T14:24:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/9s87naeckijnd6qs439icv9h1'},
#    'href': 'https://api.spotify.com/v1/users/9s87naeckijnd6qs439icv9h1',
#    'id': '9s87naeckijnd6qs439icv9h1',
#    'type': 'user',
#    'uri': 'spotify:user:9s87naeckijnd6qs439icv9h1'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2025-06-20T14:24:17Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/9s87naeckijnd6qs439icv9h1'},
#   'href': 'https://api.spotify.com/v1/users/9s87naeckijnd6qs439icv9h1',
#   'id': '9s87naeckijnd6qs439icv9h1',
#   'type': 'user',
#   'uri': 'spotify:user:9s87naeckijnd6qs439icv9h1'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
data['items'][0]['track']['type']
# Out:
# 'track'

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
# ...

# %%
data['items'][0]['track']['album']['type']
# Out:
# 'album'

# %%
data['items'][0]['track']['name']
# Out:
# 'Saiyaara (From "Saiyaara")'

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4f7KfxeHq9BiylGmyXepGt'},
#   'href': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt',
#   'id': '4f7KfxeHq9BiylGmyXepGt',
#   'name': 'Tanishk Bagchi',
#   'type': 'artist',
#   'uri': 'spotify:artist:4f7KfxeHq9BiylGmyXepGt'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/05etL4pzWd6TSv1x5WrlG3'},
#   'href': 'https://api.spotify.com/v1/artists/05etL4pzWd6TSv1x5WrlG3',
#   'id': '05etL4pzWd6TSv1x5WrlG3',
#   'name': 'Faheem Abdullah',
#   'type': 'artist',
#   'uri': 'spotify:artist:05etL4pzWd6TSv1x5WrlG3'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yzqUq3vXrMkmfcOwMY203'},
#   'href': 'https://api.spotify.com/v1/artists/5yzqUq3vXrMkmfcOwMY203',
#   'id': '5yzqUq3vXrMkmfcOwMY203',
#   'name': 'Arslan Nizami',
#   'type': 'artist',
#   'uri': 'spotify:artist:5yzqUq3vXrMkmfcOwMY203'},
# ...

# %%
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Tanishk Bagchi'

# %%
data['items'][0]['track']['artists'][3]['name']
# Out:
# 'Irshad Kamil'

# %%
data['items'][0]['track']['artists'][2]['name']
# Out:
# 'Arslan Nizami'

# %%
data['items'][0]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4f7KfxeHq9BiylGmyXepGt'},
#   'href': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt',
#   'id': '4f7KfxeHq9BiylGmyXepGt',
#   'name': 'Tanishk Bagchi',
#   'type': 'artist',
#   'uri': 'spotify:artist:4f7KfxeHq9BiylGmyXepGt'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/05etL4pzWd6TSv1x5WrlG3'},
#   'href': 'https://api.spotify.com/v1/artists/05etL4pzWd6TSv1x5WrlG3',
#   'id': '05etL4pzWd6TSv1x5WrlG3',
#   'name': 'Faheem Abdullah',
#   'type': 'artist',
#   'uri': 'spotify:artist:05etL4pzWd6TSv1x5WrlG3'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yzqUq3vXrMkmfcOwMY203'},
#   'href': 'https://api.spotify.com/v1/artists/5yzqUq3vXrMkmfcOwMY203',
#   'id': '5yzqUq3vXrMkmfcOwMY203',
#   'name': 'Arslan Nizami',
#   'type': 'artist',
#   'uri': 'spotify:artist:5yzqUq3vXrMkmfcOwMY203'},
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4f7KfxeHq9BiylGmyXepGt'},
#   'href': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt',
#   'id': '4f7KfxeHq9BiylGmyXepGt',
#   'name': 'Tanishk Bagchi',
#   'type': 'artist',
#   'uri': 'spotify:artist:4f7KfxeHq9BiylGmyXepGt'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/05etL4pzWd6TSv1x5WrlG3'},
#   'href': 'https://api.spotify.com/v1/artists/05etL4pzWd6TSv1x5WrlG3',
#   'id': '05etL4pzWd6TSv1x5WrlG3',
#   'name': 'Faheem Abdullah',
#   'type': 'artist',
#   'uri': 'spotify:artist:05etL4pzWd6TSv1x5WrlG3'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yzqUq3vXrMkmfcOwMY203'},
#   'href': 'https://api.spotify.com/v1/artists/5yzqUq3vXrMkmfcOwMY203',
#   'id': '5yzqUq3vXrMkmfcOwMY203',
#   'name': 'Arslan Nizami',
#   'type': 'artist',
#   'uri': 'spotify:artist:5yzqUq3vXrMkmfcOwMY203'},
# ...

# %%
artist_list=[]
for row in data['items']:
    artist_id=row['track']['artists'][0]['id']
    artist_list.append(artist_id)

# %%
artist_list = []  

for row in data['items']:
    for artist in row['track']['artists']:
        artist_id = artist['id']
        artist_list.append(artist_id)

# %%
artist_list
# Out:
# ['4f7KfxeHq9BiylGmyXepGt',
#  '05etL4pzWd6TSv1x5WrlG3',
#  '5yzqUq3vXrMkmfcOwMY203',
#  '3GdSQUH1BRtl9UrrtuwJlP',
#  '3ozYqVCLohfpXIhalkhM8D',
#  '5wJ1H6ud777odtZl5gG507',
#  '0RVfcqug2nB820dxIGycIW',
#  '2DFCHTDIA0t638a4mm37dK',
#  '09UmIX92EUH9hAK4bxvHx6',
#  '4YRxDV8wJFPHPTeXepOstw',
#  '0Eb38FY9vOjiRA10iXPGHI',
#  '1tqysapcCh1lWEAc9dIFpa',
#  '05etL4pzWd6TSv1x5WrlG3',
#  '22UtphG4LcwxlhhV0aP4js',
#  '6MPuzz9hPrs4TwxeHh4cEj',
#  '1SyKki7JI1AZNKwgNMkn25',
#  '6WOdPJmexxFINcKMkP2jMG',
#  '1E6arsXf5Fgsnv9YpSzjpE',
#  '3GdSQUH1BRtl9UrrtuwJlP',
#  '0ggJT2f5xy19NXiwG9IgUC',
#  '2IKfr1JgPRXmXKAWwrABc6',
#  '1zD9gVg8wPOmVfYxTjMHaT',
#  '29S4JzoFUP1MCyMgKd83zM',
#  '4f7KfxeHq9BiylGmyXepGt',
#  '05etL4pzWd6TSv1x5WrlG3',
#  '5yzqUq3vXrMkmfcOwMY203',
#  '0oOet2f43PA68X5RxKobEy',
#  '3GdSQUH1BRtl9UrrtuwJlP',
#  '5sgMlqIAv6QrTuXSgvteDt',
#  '4kcQ7gUPfqmfkayyEsluN5',
#  '4gYkupDdCRGvdDHFwQwLOr',
#  '58M48cKnFnWJs6gvhA77tX',
#  '1SyKki7JI1AZNKwgNMkn25',
#  '1E6arsXf5Fgsnv9YpSzjpE',
# ...

# %%
playlists=sp.user_playlists('spotify')

# %%
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists?offset=0&limit=50',
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/users/spotify/playlists?offset=50&limit=50',
#  'offset': 0,
#  'previous': None,
#  'total': 348,
#  'items': [{'collaborative': False,
#    'description': 'All songs about drinking, cheating, heartaches and everything else going on in a classic honky tonk.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0NfjMqrzcGKVsbYZmhf4Md'},
#    'href': 'https://api.spotify.com/v1/playlists/0NfjMqrzcGKVsbYZmhf4Md',
#    'id': '0NfjMqrzcGKVsbYZmhf4Md',
#    'images': [{'height': None,
#      'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da8430ec0eff4844b5161b5075b0',
#      'width': None}],
#    'name': 'Classic Honky Tonk',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
# ...

# %%
for playlist in playlists['items']:
    print(playlist['name'])
# Out:
# Classic Honky Tonk
# Nicholas Sparks | Songs from the Soundtracks
# 1960s Nostalgia
# Breakup Blues
# I Hate My Job.
# Instrumental Rock
# Avant Folk
# The Perfect Crafternoon
# Power Ballads
# Energy + Positivity
# Namaste
# Rustic Romance Wedding
# Word of Mouth
# Indie Strings
# Vinyasa Flow
# Acoustic Commute
# Summertime Vibes
# More Banjo!
# Chill as Folk
# The New Bohemian
# Sweetgrass
# Sweet Winter Songs
# Disco Beats
# Rock & Roots
# Interstate Drive Songs
# Low Key Revelry
# Best of 2016: Folk & Americana
# Best of 2016:  Hot Country
# Guest List: Orb
# Artists Den + Spotify
# Women in Music | Stories & Songs
# BRILLIANTMINDS2016
# Incoming
# AMY
# Follow Your Bliss
# Rest & Relaxation
# One Perfect Day
# Get Happy!
# Lazy Afternoon
# The Bridge
# Spring Garden
# Nightly Meditations
# (Descent) A Beginning
# Covered in Country
# Traffic Jams
# #JazzAppreciationMonth
# Motivation Montage
# Sugar & Spice
# Soul Soothers
# Winding Roads

# %%
for item in data['items']:
    print(item['track']['name'])
# Out:
# Saiyaara (From "Saiyaara")
# Sahiba
# Tum Ho Toh (From "Saiyaara")
# Dhun (From "Saiyaara")
# Barbaad (From "Saiyaara")
# Ishq - From "Lost;Found"
# Humsafar (From "Saiyaara")
# Finding Her
# Saiyaara Reprise - Female
# Kole Bheja
# Raanjhan (From "Do Patti")
# Jo Tum Mere Ho
# Mann Mera
# Tere Bina
# Pari
# Sajde
# Paro
# Ehsaas
# Pardesiya - From "Param Sundari"
# yaadan
# Sirra
# Apna Bana Le
# Thodi Si Daaru
# Aavan Jaavan (From "WAR 2")
# early morning vibes
# Sapphire
# Sang Rahiyo
# Ye Tune Kya Kiya
# Paaro
# raaste
# Zamaana Lage (From "Metro ... In Dino")
# Tujhe Kitna Chahne Lage (From "Kabir Singh")
# Haseen
# Humdard (From "Ek Villain")
# Kaaton
# Jeena Jeena
# Samjho Na
# Laal Pari (From "Housefull 5")
# Sahiba
# Broken Heart
# Jhol
# Agar Tum Saath Ho (From "Tamasha")
# Mere Sohneya
# Maiyya
# Don't You Love Me?
# Jo Tere Sang
# Jugraafiya - From "Super 30"
# Wavy
# Qatal
# Sitara
# Tum Hi Ho
# Ishq Bulaava
# Jhol - Acoustic
# Afsos
# Pehli Baarish
# ...
